# %% [markdown]
# # Desafio de limpeza de dados
# Nesse projeto, eu irei fazer modificações em uma tabela para torná-la pronta para uma análise de dados.

# %% [markdown]
# ### Formato atual da tabela

# %% [markdown]
# ![alt text](imagens\https://github.com/BrenoTeixeira/desafio_limpeza_de_dados/blob/main/imagens/modelo_atual.PNG)

# %% [markdown]
# ### Formato desejado

# %% [markdown]
# ![alt text](https://github.com/BrenoTeixeira/desafio_limpeza_de_dados/blob/main/imagens/modelo_desejado.PNG)

# %% [markdown]
# # Transformação de dados

# %%
# Importando as bibliotecas necessárias
import pandas as pd
import os
import numpy as np

# %%
pwd = os.getcwd()

# %%
# Carregando dados
data = pd.read_csv(pwd+'\\data_cleaning_challenge.csv')
data.head(16)
# Out:
#               Row Type       Iter Number             Power1  Speed1  Speed2  \
# 0   first name: Person  last name: Human  date: end of time     NaN     NaN
# 1                  NaN               NaN                NaN     NaN     NaN
# 2             Row Type       Iter Number             Power1  Speed1  Speed2
# 3                 Iter                 1                360     108     863
# 4                 Iter                 2                684     508     613
# 5                 Iter                 3                365     126     825
# 6                 Iter                 4                764     594     304
# 7                 Iter                 5                487      97     593
# 8              Average               182                361     741     231
# 9              Maximum               276                 33      97     154
# 10            Std.Dev.               523               1000      34     904
# 11               Total               336                  -       -       -
# 12                 NaN               NaN                NaN     NaN     NaN
# 13                 NaN               NaN                NaN     NaN     NaN
# 14  first name: Person  last name: Human  date: end of time     NaN     NaN
# 15                 NaN               NaN                NaN     NaN     NaN
#
#     Electricity  Effort  Weight  Torque  Unnamed: 9 Unnamed: 10
# 0           NaN     NaN     NaN     NaN         NaN         NaN
# 1           NaN     NaN     NaN     NaN         NaN         NaN
# 2   Electricity  Effort  Weight  Torque         NaN         NaN
# 3           599     680     442     982         NaN         NaN
# 4           241     249     758     639         NaN         NaN
# 5           407     855     164      86         NaN         NaN
# 6           718     278     674     774         NaN         NaN
# 7           206     779     800     123         NaN         NaN
# 8           731     493     847     237         NaN         NaN
# 9            25     922       9     312         NaN         NaN
# 10          237     600     170     553         NaN         NaN
# 11            -     977     744     652         NaN         NaN
# 12          NaN     NaN     NaN     NaN         NaN         NaN
# 13          NaN     NaN     NaN     NaN         NaN         NaN
# 14          NaN     NaN     NaN     NaN         NaN         NaN
# 15          NaN     NaN     NaN     NaN         NaN         NaN

# %%
data_c = data.copy()

# %% [markdown]
# #### Removendo colunas extras e linhas desnecessárias utilizando os metódos `dropna` e `drop`.

# %%
# Removendo as linnhas onde todos os valores são nulos.
data_new = data_c.dropna(axis=0, how='all')

# Removendo as duas colunas extras.
data_new = data_new.drop(columns=['Unnamed: 9', 'Unnamed: 10'])

# %%
# Checando modificações
data_new.head(20)
# Out:
#               Row Type       Iter Number             Power1  Speed1  Speed2  \
# 0   first name: Person  last name: Human  date: end of time     NaN     NaN
# 2             Row Type       Iter Number             Power1  Speed1  Speed2
# 3                 Iter                 1                360     108     863
# 4                 Iter                 2                684     508     613
# 5                 Iter                 3                365     126     825
# 6                 Iter                 4                764     594     304
# 7                 Iter                 5                487      97     593
# 8              Average               182                361     741     231
# 9              Maximum               276                 33      97     154
# 10            Std.Dev.               523               1000      34     904
# 11               Total               336                  -       -       -
# 14  first name: Person  last name: Human  date: end of time     NaN     NaN
# 16            Row Type       Iter Number             Power1  Speed1  Speed2
# 17                Iter                 1                702     494     311
# 18                Iter                 2                929      82     838
# 19                Iter                 3                763     402     344
# 20                Iter                 4                469     930     560
# 21                Iter                 5                688     145      41
# 22             Average                66                307     835     615
# 23             Maximum               329                402     777     664
#
#     Electricity  Effort  Weight  Torque
# 0           NaN     NaN     NaN     NaN
# 2   Electricity  Effort  Weight  Torque
# 3           599     680     442     982
# 4           241     249     758     639
# 5           407     855     164      86
# 6           718     278     674     774
# 7           206     779     800     123
# 8           731     493     847     237
# 9            25     922       9     312
# 10          237     600     170     553
# 11            -     977     744     652
# 14          NaN     NaN     NaN     NaN
# 16  Electricity  Effort  Weight  Torque
# 17          492     456     370     150
# 18          421     154     346     227
# 19          951     139     295     285
# 20          395     433     237     429
# 21          188     534     778     152
# 22          731     943     460      76
# 23           98      44     932     409

# %% [markdown]
# #### Criando as colunas `First Name`, `Last Name` e `Date`

# %%
data_new['First Name'] = data_new['Row Type']
data_new['Last Name'] = data_new['Iter Number']
data_new['Date'] = data_new['Power1']

# %% [markdown]
# #### Preenchendo as novas colunas

# %%
# Transformando os valores que não são relevantes para as novas colunas em valores nulos. 
data_new['First Name'] = data_new['First Name'].apply(lambda x: x if x.lower().__contains__('first name') else np.nan)
data_new['Last Name'] = data_new['Last Name'].apply(lambda x: x if x.lower().__contains__('last name') else np.nan)
data_new['Date'] = data_new['Date'].apply(lambda x: x if x.lower().__contains__('date') else np.nan)

# %% [markdown]
# Preechendo as novas colunas utilizando a função `fillna` com o método 'ffill' (propaga o último valor válido até o próximo valor válido).

# %%
data_fill = data_new.copy()
data_fill[['First Name', 'Last Name', 'Date']] = data_fill[['First Name', 'Last Name', 'Date']].fillna(method='ffill')

# %% [markdown]
# Removendo a parte desnecessária ('first name:', 'last name:' e 'date:') dos valores preenchidos.

# %%
data_fill[['First Name', 'Last Name', 'Date']] = data_fill[['First Name', 'Last Name', 'Date']].applymap(lambda x: x.split(":")[1].strip())

# %%
# Checando modificações
data_fill.head(20)
# Out:
#               Row Type       Iter Number             Power1  Speed1  Speed2  \
# 0   first name: Person  last name: Human  date: end of time     NaN     NaN
# 2             Row Type       Iter Number             Power1  Speed1  Speed2
# 3                 Iter                 1                360     108     863
# 4                 Iter                 2                684     508     613
# 5                 Iter                 3                365     126     825
# 6                 Iter                 4                764     594     304
# 7                 Iter                 5                487      97     593
# 8              Average               182                361     741     231
# 9              Maximum               276                 33      97     154
# 10            Std.Dev.               523               1000      34     904
# 11               Total               336                  -       -       -
# 14  first name: Person  last name: Human  date: end of time     NaN     NaN
# 16            Row Type       Iter Number             Power1  Speed1  Speed2
# 17                Iter                 1                702     494     311
# 18                Iter                 2                929      82     838
# 19                Iter                 3                763     402     344
# 20                Iter                 4                469     930     560
# 21                Iter                 5                688     145      41
# 22             Average                66                307     835     615
# 23             Maximum               329                402     777     664
#
#     Electricity  Effort  Weight  Torque First Name Last Name         Date
# 0           NaN     NaN     NaN     NaN     Person     Human  end of time
# 2   Electricity  Effort  Weight  Torque     Person     Human  end of time
# 3           599     680     442     982     Person     Human  end of time
# 4           241     249     758     639     Person     Human  end of time
# 5           407     855     164      86     Person     Human  end of time
# 6           718     278     674     774     Person     Human  end of time
# 7           206     779     800     123     Person     Human  end of time
# 8           731     493     847     237     Person     Human  end of time
# 9            25     922       9     312     Person     Human  end of time
# 10          237     600     170     553     Person     Human  end of time
# 11            -     977     744     652     Person     Human  end of time
# 14          NaN     NaN     NaN     NaN     Person     Human  end of time
# 16  Electricity  Effort  Weight  Torque     Person     Human  end of time
# 17          492     456     370     150     Person     Human  end of time
# 18          421     154     346     227     Person     Human  end of time
# 19          951     139     295     285     Person     Human  end of time
# 20          395     433     237     429     Person     Human  end of time
# 21          188     534     778     152     Person     Human  end of time
# 22          731     943     460      76     Person     Human  end of time
# 23           98      44     932     409     Person     Human  end of time

# %% [markdown]
# #### Removendo linhas com os nomes das colunas.

# %%
data_formated = data_fill.loc[~data_fill['Row Type'].isin(['Row Type', 'first name: Person'])]

# %%
# Checando modificações
display(data_formated)
# Out:
#        Row Type Iter Number Power1 Speed1 Speed2 Electricity Effort Weight  \
# 3          Iter           1    360    108    863         599    680    442
# 4          Iter           2    684    508    613         241    249    758
# 5          Iter           3    365    126    825         407    855    164
# 6          Iter           4    764    594    304         718    278    674
# 7          Iter           5    487     97    593         206    779    800
# ...         ...         ...    ...    ...    ...         ...    ...    ...
# 76372      Iter           6    879     73    977         680    500    395
# 76373   Average         979    641    531    374         448    407    185
# 76374   Maximum         783    172    941     53         982    217    963
# 76375  Std.Dev.         221    112    717    630         239    561    142
# 76376     Total         429      -      -      -           -    847    583
#
#       Torque First Name Last Name         Date
# 3        982     Person     Human  end of time
# 4        639     Person     Human  end of time
# 5         86     Person     Human  end of time
# 6        774     Person     Human  end of time
# 7        123     Person     Human  end of time
# ...      ...        ...       ...          ...
# 76372    863     Person     Human  end of time
# 76373    439     Person     Human  end of time
# 76374    502     Person     Human  end of time
# 76375    909     Person     Human  end of time
# 76376    407     Person     Human  end of time
#
# [46409 rows x 12 columns]

# %% [markdown]
# #### Reordenando as colunas da tabela.

# %%
labels = ['First Name','Last Name','Date', 'Row Type', 'Iter Number','Power1','Speed1','Speed2','Electricity','Effort','Weight','Torque']

data_final = data_formated.reset_index().drop(columns='index').reindex(labels, axis=1)

# %%
display(data_final)
# Out:
#       First Name Last Name         Date  Row Type Iter Number Power1 Speed1  \
# 0         Person     Human  end of time      Iter           1    360    108
# 1         Person     Human  end of time      Iter           2    684    508
# 2         Person     Human  end of time      Iter           3    365    126
# 3         Person     Human  end of time      Iter           4    764    594
# 4         Person     Human  end of time      Iter           5    487     97
# ...          ...       ...          ...       ...         ...    ...    ...
# 46404     Person     Human  end of time      Iter           6    879     73
# 46405     Person     Human  end of time   Average         979    641    531
# 46406     Person     Human  end of time   Maximum         783    172    941
# 46407     Person     Human  end of time  Std.Dev.         221    112    717
# 46408     Person     Human  end of time     Total         429      -      -
#
#       Speed2 Electricity Effort Weight Torque
# 0        863         599    680    442    982
# 1        613         241    249    758    639
# 2        825         407    855    164     86
# 3        304         718    278    674    774
# 4        593         206    779    800    123
# ...      ...         ...    ...    ...    ...
# 46404    977         680    500    395    863
# 46405    374         448    407    185    439
# 46406     53         982    217    963    502
# 46407    630         239    561    142    909
# 46408      -           -    847    583    407
#
# [46409 rows x 12 columns]

# %%
# Salvando 
data_final.to_csv(pwd+'\\Data_final_output.csv', index=False)
